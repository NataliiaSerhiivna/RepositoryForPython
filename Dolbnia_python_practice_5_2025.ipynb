# %% [markdown]
# # I. OOP

# %% [markdown]
# 1. (6б). Створіть клас Building, додайте три атрибути, один з яких має значення за замовчуванням та два методи на свій розсуд.

# %%
class Building:
  def __init__(self, id, local_address, city="Kyiv"):
    self.id = id
    self.city = city
    self.local_address = local_address

  def find_id(self):
    return self.id
  def address(self):
    return f"Building is located in {self.city}, address: {self.local_address}"

# %% [markdown]
# 2. (2б). Створіть два обʼєкти цього класу, де один з обʼєктів створюється із дефолтним значенням атрибуту. На одному обʼєкті отримайте значення його атрибуту, а на іншому викличте один з його методів.

# %%
b1 = Building(1, "Park ave 10", "Lviv")
b2 = Building(2, "Olecsandry Ekster 14")

print(b1.city)
print(b2.address())
# Out:
# Lviv
# Building is located in Kyiv, address: Olecsandry Ekster 14

# %% [markdown]
# 3. (5б). Створіть клас, де атрибути мають різні рівні доступу. Спробуйте отримати їхні значення та опишіть результати.

# %%
class Building:
  def __init__(self, id, local_address, city="Kyiv"):
    self.__id = id
    self.city = city
    self._local_address = local_address

b1 = Building(1, "Park ave 10", "Lviv")

print(b1.city) # все  виводить
print(b1._local_address) # все виводить
#print(b1.__id) #AttributeError
print(b1._Building__id) #все виводить в такому випадку
# Out:
# Lviv
# Park ave 10
# 1

# %% [markdown]
# 4. (7б). Як ви розумієте термін self? Для чого використовується метод __init __?

# %% [markdown]
# self - посилання на поточний об’єкт, який от зараз є на прийомі.
#  __init __ - виконує роль констріктора, ООП в пайтоні

# %% [markdown]
# 5. (9б). Створіть клас 3D-фігура без атрибутів, з методом get_volume для отримання об'єму фігури, що повертає 0 та __add __, який приймає self та other в якості аргументів, а повертає суму об'ємів 3d-фігур self та other.

# %%
class Figure3D:
  def get_volume(self):
    return 0

  def __add__(self, other):
    return self.get_volume() + other.get_volume()

# %% [markdown]
# 6. (11б). Створіть 2 дочірніх класи від 3d-фігура: Циліндр та Куб, які мають атрибути, необхідні для розрахунку об'єму. Визначте метод get_volume в кожному з них так, щоби вони розраховували об'єм у залежності від формули для кожного типу фігури. Створіть обʼєкт класу Циліндр та обʼєкт класу Куб. Виконайте операцію суми за допомогою оператора + між ними, аби знайти сумарний об'єм.

# %%
class Cylinder(Figure3D):
  def __init__(self, radius, height):
      self.radius = radius
      self.height = height
  def get_volume(self):
      return 3.14 * (self.radius ** 2) * self.height

class Cube(Figure3D):
  def __init__(self, side):
      self.side = side
  def get_volume(self):
      return self.side ** 3


cylinder = Cylinder(2, 10)
cube = Cube(3)

print("Сума = ", f"{cylinder + cube:.4f}")
# Out:
# Сума =  152.6000

# %% [markdown]
# 7. (3б). Продемонструйте різницю між isinstance та issubclass.

# %%
print(isinstance(cylinder, Figure3D)) # isinstance працює з об'єктами - cylinder
print(issubclass(Cylinder, Figure3D)) # issubclass працює з класами - Cylinder
# Out:
# True
# True

# %% [markdown]
# 8. (13б). Створіть клас EWallet з приватними атрибутами balance та id. Реалізуйте методи поповнення та зняття коштів, забезпечивши належну інкапсуляцію. Підказка: використовуйте декоратори property та setter.

# %%
class EWallet:
  def __init__(self, id, balance=0):
      self.__id = id
      self.__balance = balance

  @property
  def balance(self):
    return self.__balance

  @property
  def id(self):
    return self.__id

  @balance.setter
  def balance(self, value):
    raise AttributeError("Balance cannot be set directly (deposit/withdraw)")

  def deposit(self, amount):
    if amount <= 0:
      raise ValueError("Amount must be >0")
    self.__balance += amount

  def withdraw(self, amount):
    if amount <= 0:
      raise ValueError("Amount must be >0")
    if amount > self.__balance:
      raise ValueError("Not enough funds.")
    self.__balance -= amount


w1 = EWallet("001", 100)
w1.deposit(50)
w1.withdraw(30)
print("id: ", w1.id, "balance: ", w1.balance)
# Out:
# id:  001 balance:  120

# %% [markdown]
# 9. (11б). Створіть клас ShoppingCart, який містить список об'єктів типу Item. Реалізуйте методи для додавання айтемів, їх видалення та відображення списку айтемів.

# %%
class Item:
  def __init__(self, name, price):
    self.name = name
    self.price = price
  def __repr__(self):
    return f"Item(name={self.name!r}, price={self.price})"

class ShoppingCart:
  def __init__(self):
    self.items = []

  def add_item(self, item):
    self.items.append(item)

  def remove_item(self, name):
    for i, it in enumerate(self.items):
      if it.name == name:
        self.items.pop(i)
        return True
    return False

  def show_items(self):
      print(self.items)


cart = ShoppingCart()
cart.add_item(Item("Bread", 25))
cart.add_item(Item("Milk", 52))
cart.show_items()
cart.remove_item("Bread")
cart.show_items()
# Out:
# [Item(name='Bread', price=25), Item(name='Milk', price=52)]
# [Item(name='Milk', price=52)]

# %% [markdown]
# 10. (13б). Створіть клас Vehicle з атрибутами brand (manufacturer) та production_age. Створіть ще один клас Engine з такими атрибутами, як type (ex. petrol) та size (volume, litres). Створіть клас Car, який успадковує обидва класи Vehicle та Engine. Продемонструйте використання множинної спадковості, створивши обʼєкт класу Car та отримавши mro для цього класу.

# %%
class Vehicle:
  def __init__(self, brand, production_age):
    self.brand = brand
    self.production_age = production_age

class Engine:
  def __init__(self, e_type, size):
    self.e_type = e_type
    self.size = size


class Car(Vehicle, Engine):
  def __init__(self, brand, production_age, e_type, size):
    Vehicle.__init__(self, brand, production_age)
    Engine.__init__(self, e_type, size)


car = Car("Toyota", 5, "petrol", 2.0)
print("mro:", Car.mro())
print("Машина:", car.brand, car.e_type)
# Out:
# mro: [<class '__main__.Car'>, <class '__main__.Vehicle'>, <class '__main__.Engine'>, <class 'object'>]
# Машина: Toyota petrol

# %% [markdown]
# # II. Iterator

# %% [markdown]
# 11. (4б). Визначте рядок(str) з 4ма різними за значенням символами. Створіть ітератор на основі цього рядка. Викличте 5 разів функцію next на ітераторі, 4ри перших з них огорніть у ф-цію print().

# %%
s1 = "abcd"
it = iter(s1)

print(next(it))
print(next(it))
print(next(it))
print(next(it))
#next(it) # StopIteration
# Out:
# a
# b
# c
# d

# %% [markdown]
# А що якщо викликати цю ж функцію на рядку?

# %%
next(s1) # TypeError: 'str' object is not an iterator
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1088000604.py in <cell line: 0>()
# ----> 1 next(s1) # TypeError: 'str' object is not an iterator
#
# TypeError: 'str' object is not an iterator

# %% [markdown]
#  12. (5б). Опишіть своїми словами в одному реченні, як ви розумієте різницю між ітерабельними обʼєктами та ітераторами (можна на прикладі).

# %% [markdown]
# Iterable - об’єкт, по якому можна пройтись отак iter(obj), а iterator - об’єкт, який зберігає стан обходу, типу може повернути наступний елемент через next()

# %% [markdown]
# 13. (11б). Створіть клас, що має визначений Iterator Protocol та при кожному виклику next повертає назву дня тижня, поки вони не вичерпаються. Зверніть увагу, що порядок має значення.

# %%
class Week:
  def __init__(self):
    self.days = ["Mon", "Tue", "Wed", "Thu", "Fri", "Sat", "Sun"]
    self.index = 0

  def __iter__(self):
    return self

  def __next__(self):
    if self.index >= len(self.days):
        raise StopIteration
    day = self.days[self.index]
    self.index += 1
    return day


w1 = Week()
for d in w1:
  print(d)
# Out:
# Mon
# Tue
# Wed
# Thu
# Fri
# Sat
# Sun

# %% [markdown]
# # Вітаю! Ви велика(ий) молодець, що впоралась(вся). Похваліть себе та побалуйте чимось приємним. Я Вами пишаюся.
